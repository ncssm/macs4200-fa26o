# %%
# Initialize Otter
import otter
grader = otter.Notebook("lab02.ipynb")

# %% [markdown]
# # Lab 02: The `LETTERS` string
#
# ## Today's lab
#
# The goals of this lab activity:
# * Understand the `LETTERS` string, and how it can convert characters into a numerical representation
# * Perform modular reduction using Python's `%` operator
# * Encipher individual letters using the Caesar shift
#
# This lab covers parts of [Chapter 4](https://macs4200.org/chapters/04/2/caesar-cipher) of the online textbook. You should read the examples in the book, but not right now. Instead, let's get started!

# %% [markdown]
# <hr style="border: 5px solid #346094;" />
# <hr style="border: 1px solid #f4c300;" />
#
# # Part 1: Our Alphabet
#
# In this course, unless otherwise noted, you can assume plaintext and ciphertext are characters from the English language. We will need a reliable and consistent way of converting these characters into an equivalent numerical form.
#
# While there are more sophisticated and modern ways of converting characters to numbers, and vice versa, in this course we'll use a string called `LETTERS` to hold the characters of our alphabet, where the index of the character is the numerical representation of that character. This allows us to use string indexing, `LETTERS[...]` to quickly compute the characters that correspond to a particular numerical value.

# %%
LETTERS = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %% [markdown]
# For example,
# *  Since `LETTERS[0]` is `'A'`, $A \rightarrow 0$
# *  Since `LETTERS[3]` is `'D'`, $D \rightarrow 3$
#
# So, the characters `M`, `A`, `T`, and `H` could be converted to the equivalent numerical values of: `12`, `0`, `19`, `7`

# %% [markdown]
# ### Question 1
#
# Suppose we "extend" our usual alphabet to include lowercase letters and some punctuation. We'll call it `BIGLETTERS` and define it in the code cell below.

# %%
BIGLETTERS = 'ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz!@#$%^&*()'

# %% [markdown]
# Fill in the `...` in the code cell below to compute the characters in `BIGLETTERS` that correspond to the numerical values of 31, 44, 47, and 53. You should use string indexing to determine the values.

# %%
character_31 = ...
character_44 = ...
character_47 = ...
character_53 = ...

print(character_31, character_44, character_47, character_53)

# %%
grader.check("q1")

# %% [markdown]
# ### Question 2
#
# We could even create an "emoji alphabet", where the alphabet contains every emoji. We'll call this alphabet `EMOJI`.

# %%
EMOJI = '😀😃😄😁😆🥹😅😂🤣😍😌😉🙃🙂😇😊☺️🥲🥰😘😗😙😚😋😛😝😜😏🥳🤩🥸😎🤓🧐🤨🤪😒😞😔😟😕🙁☹️😣😖🤬😡😠😤😭😢🥺😩😫🤯😳🥵🥶😶‍🌫️😱😨😰😥🫠🤫🫡🫢🤭🫣🤔🤗😓🤥😶🫥😐🫤😑😬🙄😯😮‍💨😪🤤😴🥱😲😮😧😦😵😵‍💫🤐🥴🤢🤮🤧😷🤒💩🤡👺👹👿😈🤠🤑🤕👻💀☠️👽👾🤖🎃😺😸🤲🫶😾😿🙀😽😼😻😹👐🙌👏🤝👍👎✊🤛👊🤏🤌👌🤘🤟🫰✌️🤞🤜🫳🫴👈👉👆👇☝️✋🤚🖕🦾💪🫱🫲🤙👋🖖🖐✍️🙏🫵🦶🦵🦿💄💋👄👀👁👣👃🦻👂👅🦷🫦🫀🫁🧠🗣👤👥🫂👶👧👩‍🦰👨‍🦱🧑‍🦱👩‍🦱👨🧑👩👦🧒🧑‍🦰👨‍🦰👱‍♀️👱👱‍♂️👩‍🦳🧑‍🦳👨‍🦳👩‍🦲👲👴🧓👵🧔‍♂️🧔🧔‍♀
��🇻🇪🇵🇹🇧🇴🇧🇼🇧🇦🇵🇱🇧🇪🇵🇪🇧🇿🇧🇾🇭🇳🇲🇭🇲🇴🇲🇬🇾🇹🇲🇼🇲🇱🇲🇹🇲🇶🇲🇨🇲🇿🇲🇷🇲🇺🇲🇽🇲🇲🇫🇲🇮🇲🇲🇾🇲🇻🇲🇩🇲🇦🇲🇳🇲🇪🇲🇸🇯🇴🇱🇻🇱🇧🇱🇸🇷🇼🇱🇺🇷🇴🇱🇷🇱🇮🇱🇾🇱🇹🇷🇪🇷🇺🇻🇬🇪🇺🇰🇷🇪🇭🇭🇰🇬🇶🇨🇫🇨🇳🇹🇱🇸🇸🇦🇶🇯🇵🎌🇬🇫🇵🇫🇰🇵🇲🇵🇲🇰🇦🇸🇻🇮🇹🇫✡✳✴❇☯✂☘✉✔✘⚧✏✒♟'

# %% [markdown]
# For example,
# *  Since `EMOJI[0]` is `'😀'`, $😀 \rightarrow 0$
# *  Since `EMOJI[3]` is `'😁'`, $😁 \rightarrow 3$

# %% [markdown]
# Use string indexing to determine the emoji that are equivalent to numbers 100, 150, and 200.

# %%
emoji_100 = ...
emoji_150 = ...
emoji_200 = ...

print(emoji_100, emoji_150, emoji_200)

# %%
grader.check("q2")

# %% [markdown]
# <hr style="border: 5px solid #346094;" />
# <hr style="border: 1px solid #f4c300;" />

# %% [markdown]
# ## Part 2: Converting Letters to Numbers
#
# It will also be important that we can convert numerical representations back into their characters, as it is often easier to transmit characters instead of raw numerical data. To convert numbers into their equivalent character, we can use the `.find()` method.
#
# The `A.find(B)` method looks for string `B` inside of string `A`, and if it finds it, returns the index of string `A` where it was found.
#
# For example,
# * `'😀😃😄😁😆🥹'.find('😆')` would return 4, since the string `'😆'` is found at index 4 inside of the string `'😀😃😄😁😆🥹`.
# * `LETTERS.find('C')` would return 2, since the string `'C'` is found at index 2 inside of the string `LETTERS`.

# %% [markdown]
# ### Question 3
#
# Use the `.find()` method with the `BIGLETTERS` alphabet to decode the following message, provided as a sequence of numbers:
#
# `0, 28, 26, 29, 34, 26, 52`
#
# When you've determined the plaintext word, assign it as a string to the variable `park`.

# %%
# Write your code here to determine the corresponding characters in BIGLETTERS
# Use a print statement to help see the results of any intermediate calculations
...

park = ...

# %%
grader.check("q3")

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### Question 4
#
# What happens if you try to use the `A.find(B)` method, but Python can't find the substring B instead of the string A? Write code where this happens, and then describe what you observe.
#
# Is there an error message? If yes, what does the error message look like? If no, what happens?

# %%
# Write your code here to investigate
...

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# ### Question 5
#
# There is another Python method `.index()` that works very similarly to `.find()`, but operates differently when it can't find a substring A in the larger string B.
#
# **Investigate the difference in the code cell below, and explain why you might want to choose `.index()` instead of `.find()`.**

# %%
# Explore the difference between index and find
...

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# <hr style="border: 5px solid #346094;" />
# <hr style="border: 1px solid #f4c300;" />

# %% [markdown]
# ## Part 3: The Caeser Cipher
#
#
# ### The Modulo Operator
#
# The modulo operator, `%`, in Python computes the remainder after division. Running the command `7 % 3` is equivalent to solving the mathematical statement: $7 \equiv x \pmod 3$, where the `%` operation yields the smallest positive value for $x$.
#
# Evaluate by hand, then check using Python:
# * `7 % 26`
# * `26 % 26`
# * `27 % 26`
# * `30 % 26`
# * `52 % 26`

# %%
# Use this code cell to explore how the % operator works
...

# %% [markdown]
# ### Question 6
#
# The Caesar cipher is an **additive cipher**, which means that to encipher a character from plaintext to ciphertext, you **add an integer value**, which we call the *key*, to the numerical representation of the plaintext character to determine the numerical representation of the ciphertext character.
#
#
# For example:
# * If our `key = 5`, then plaintext `b`, which numerically is `1`, becomes `6`, which corresponds to `G`
# * If our `key = 11`, then plaintext `h`, which numerically is `7`, becomes `18`, which corresponds to `S`
#
# Fill in the sections of `...` so the code in the cell below computes the **numerical values** of the ciphertext characters that correspond to the plaintext word  `MATH` when using the key value of `3`.

# %%
key = ...

M_ciphertext_number = LETTERS.index(...) + ...
A_ciphertext_number = ...
T_ciphertext_number = ...
H_ciphertext_number = ...

print(M_ciphertext_number, A_ciphertext_number, T_ciphertext_number, H_ciphertext_number)

# %%
grader.check("q6")

# %% [markdown]
# ### Question 7
#
# Now, fill in the sections of `...` so the code in the cell below determines the **ciphertext characters** that correspond to the plaintext word `MATH` when using the key value of 5. You should be able to encipher each individual character using a single line of code.

# %%
key = ...

M_enciphered = LETTERS[ LETTERS.index( ... ) + ... ]
A_enciphered = LETTERS[ ... ]
T_enciphered = ...
H_enciphered = ...

print(M_enciphered, A_enciphered, T_enciphered, H_enciphered)

# %%
grader.check("q7")

# %% [markdown]
# You may have already noticed that there are combinations of key values and plaintext numerical representations that sum to a value larger than 25, which means we obtain a ciphertext numerical value that doesn't have a corresponding letter.
#
# For example,
#
# If `key = 15` and the plaintext character is `q`, then the ciphertext numerical value is `15 + 16 = 31`. There is no character in `LETTERS` with a corresponding value of `31`.
#
# However, there is an equivalent numerical value between 0 and 25 to 31 that we can use instead. The modulo operator, `%` can compute the corresponding value!
#
# For example, `31 % 26` computes 5, which is equivalent to `F`.

# %% [markdown]
# ### Question 8
#
# Fill in the `...` sections below so the code determines the **ciphertext characters** that correspond to the plaintext word `DOG` when using the **key value of 23**. Your code should work even if the result of adding the key to the plaintext value results in a number that's too large for the alphabet. You can copy/paste some of your code from the previous question to get started.

# %%
key = ...

D_enciphered = ...
O_enciphered = ...
G_enciphered = ...

print(D_enciphered, O_enciphered, G_enciphered)

# %%
grader.check("q8")

# %% [markdown]
# ## Question 9
# The Hawaiian alphabet (*in Hawaiian: ka pīʻāpā Hawaiʻi*) only has 13 characters: A, E, I, O, U, H, K, L, M, N, P, W, and '. We will define this set of characters as `HAWAIIAN` in Python using the cell of code below.

# %%
HAWAIIAN = "AEIOUHKLMNPW'"

# %% [markdown]
# Write Python code below that **deciphers** the each character of the ciphertext message `HLIWI` using a key value of 15, and the alphabet `HAWAIIAN`
#
# **HINT:** Think about how you will need to change your code from the previous questions to account for the fact that you are **deciphering** AND are using an alphabet with **13 characters**, not the 26 found in `LETTERS`.

# %%
key = ...

H_deciphered = ...
L_deciphered = ...
I_deciphered = ...
W_deciphered = ...
I_deciphered = ...

print(H_deciphered, L_deciphered, I_deciphered, W_deciphered, I_deciphered)

# %%
grader.check("q9")

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit.

# %%
grader.export(pdf=False, force_save=True)
